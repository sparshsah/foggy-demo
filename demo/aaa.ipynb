# %%
from __future__ import annotations

from collections import OrderedDict
from typing import Final
from importlib import reload

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import foggy_statslib.core as fc\


toy_ser_a: Final = pd.Series([3.14, 2.72, 42, None, 1.62], dtype=float, name="A")
toy_ser_b: Final = pd.Series([-2, -1, 1, 0, 7], dtype=int, name="B")
toy_ser_c: Final = pd.Series([False, True, True, False, True], dtype=bool, name="C")
toy_ser_d: Final = pd.Series(["pi",  "e", "atlue", None, "phi"], dtype="string", name="D")
toy_df: pd.DataFrame = pd.concat(
    [toy_ser_a, toy_ser_b, toy_ser_c, toy_ser_d],
    axis="columns",
)

# %%
reload(fc)
# Out:
# <module 'foggy_statslib.core' from '/Users/sparshsah/Documents/biz/foggyBASIS/sys/foggy-statslib/foggy_statslib/core.py'>

# %%
toy_df.loc[3, "D"] = "foo"
toy_df
# Out:
#        A  B      C      D
# 0   3.14 -2  False     pi
# 1   2.72 -1   True      e
# 2  42.00  1   True  atlue
# 3    NaN  0  False    foo
# 4   1.62  7   True    phi

# %%
fc.plot_eda(toy_df)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
